# %%
y=1
print(type(y))
y='John'
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
class Duck:
    def walk_swim(self):
        print("I am a Duck, I can do both walking and swimming.")

class Person:
    def walk_swim(self):
        print("I am a Person, I can do both walking and swimming.")

class Fish:
    def swim(self):
        print("I am a Fish, I can only swim but cant walk")

for obj in (Duck(),Person(),Fish()):
    obj.walk_swim()
# Out:
# I am a Duck, I can do both walking and swimming.
# I am a Person, I can do both walking and swimming.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 14
#      11         print("I am a Fish, I can only swim but cant walk")
#      13 for obj in (Duck(),Person(),Fish()):
# ---> 14     obj.walk_swim()
#
# AttributeError: 'Fish' object has no attribute 'walk_swim'

# %%
class Duck:
    def walk_swim(self):
        print("I am a Duck, I can do both walking and swimming.")

    def sound(self):
        print("I am Duck with sound 'Bak Bak!!'")

class Person:
    def walk_swim(self):
        print("I am a Person, I can do both walking and swimming.")

    def sound(self):
        print("I am Persom with sound 'Hii!'")
        
class Fish:
    def swim(self):
        print("I am a Fish, I can only swim but cant walk")

    def sound(self):
        print("I am Fish with sound 'Chap Chap!!'")

for obj in (Duck(),Person(),Fish()):
    obj.sound()
# Out:
# I am Duck with sound 'Bak Bak!!'
# I am Persom with sound 'Hii!'
# I am Fish with sound 'Chap Chap!!'

# %%
num1=1
num2=2
print(num1+num2)

s1="Python"
s2=" Programming"
print(s1+s2)
# Out:
# 3
# Python Programming

# %%
class Quantity:
    def __init__(self,y1,y2):
        self.y1=y1
        self.y2=y2

    def __str__(self):
        return "{},{}".format(self.y1,self.y2)

q1=Quantity(1,2)
q2=Quantity(4,5)
print(q1)
print(q2)

print(q1+q2)
# Out:
# 1,2
# 4,5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 14
#      11 print(q1)
#      12 print(q2)
# ---> 14 print(q1+q2)
#
# TypeError: unsupported operand type(s) for +: 'Quantity' and 'Quantity'

# %%
class Quantity:
    def __init__(self,y1,y2):
        self.y1=y1
        self.y2=y2

    def __str__(self):
        return "{},{}".format(self.y1,self.y2)

    def __add__(self,other):
        y1=self.y1+other.y1
        y2=self.y2+other.y2
        return (y1,y2)

q1=Quantity(1,2)
q2=Quantity(4,5)
print(q1)
print(q2)

print(q1+q2)
# Out:
# 1,2
# 4,5
# (5, 7)

# %%
class Quantity:
    def __init__(self,y1,y2):
        self.y1=y1
        self.y2=y2

    def __str__(self):
        return "{},{}".format(self.y1,self.y2)

    def __add__(self,other):
        y1=self.y1+other.y1
        y2=self.y2+other.y2
        return (y1,y2)

    def __sub__(self,other):
        y1=self.y1-other.y1
        y2=self.y2-other.y2
        return (y1,y2)

q1=Quantity(1,2)
q2=Quantity(4,5)
print(q1)
print(q2)

print(q1+q2)
print(q1-q2)
# Out:
# 1,2
# 4,5
# (5, 7)
# (-3, -3)

# %%
class Point:
    def __init__(self,x=0,y=0):
        self.x=x
        self.y=y

    def __sub__(self,other):
        x=self.x+other.x
        y=self.y+other.y
        return Point(x,y)

p1=Point(3,4)
p2=Point(1,2)
result=p1-p2
print(result.x,result.y)
# Out:
# 4 6

# %%
print(len("Manvith"))
print(len([1,2,3,5]))
# Out:
# 7
# 4

# %%
class Total:
    def add(self,x,y):
        s=x+y
        return s

    def add(self,x,y,z):
        s=x+y+z
        return s
t=Total()
t.add(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 10
#       8         return s
#       9 t=Total()
# ---> 10 t.add(1,2)
#
# TypeError: Total.add() missing 1 required positional argument: 'z'

# %%
# Note in the above one we can see that python only stores latest method. 
# So Python does not support method overloading.
# But there is a pythonic way to do this by using default arguments, which is shown below

# %%
class Total:
    def add(self,x=None,y=None,z=None):
        if x!=None and y!=None and z!=None:
            print(x+y+z)
        else:
            print(x+y)

obj=Total()
obj.add(10,20)
obj.add('Manvith is a ','Data Scientist.')
obj.add(1,2,3)
# Out:
# 30
# Manvith is a Data Scientist.
# 6

# %%
class Product:
    def mult(self,x=None,y=None,z=None):
        if x!=None and y!=None and z!=None:
            print(x*y*z)
        else:
            print(x*y)
p=Product()
p.mult(12,2)
p.mult(1,2,3)
# Out:
# 24
# 6

# %% [markdown]
# ### Method Overriding

# %%
class Bird:
    def intro(self):
        print("There are many type like us")
    def flight(self):
        print("We fly most of the time")

class Parrot(Bird):
    def flight(self):
        print("I love to fly")

class Emu(Bird):
    def flight(self):
        print("I do not like to fly")

ob=Bird()
ob.intro()
ob.flight()

print()

op=Parrot()
op.intro()
op.flight()

print()

oe=Emu()
oe.intro()
oe.flight()
# Out:
# There are many type like us
# We fly most of the time
#
# There are many type like us
# I love to fly
#
# There are many type like us
# I do not like to fly

# %%
class Bird:
    def intro(self):
        print("There are many type like us")
    def flight(self):
        print("We fly most of the time")

class Parrot(Bird):
    def intro(self):
        print("I am a Parrot")
    def flight(self):
        print("I love to fly")

class Emu(Bird):
    def intro(self):
        print("I am an Emu")
    def flight(self):
        print("I do not like to fly")

ob=Bird()
ob.intro()
ob.flight()

print()

op=Parrot()
op.intro()
op.flight()

print()

oe=Emu()
oe.intro()
oe.flight()
# Out:
# There are many type like us
# We fly most of the time
#
# I am a Parrot
# I love to fly
#
# I am an Emu
# I do not like to fly

# %%
class Fish:
    def swim(self):
        print("Fish is now swimming")
    def swim_backwards(self):
        print("Fish can also swim backwards")
    def skeleton(self):
        print("Fish has a skeleton.")

class Shark(Fish):
    def swim(self):
        print("Shark is swimming")
    def swim_backwards(self):
        print("Shark cannot swim backwards")
    def skeleton(self):
        print("Shark's skeleton is made up of cartilage")

class ClownFish(Fish):
    def swim(self):
        print("ClownFish can swim")
    def swim_backwards(self):
        print("ClownFish can swim backwards")
    def skeleton(self):
        print("ClownFIsh's skeleton is made up of Bone.")

# %%
s=Shark()
s.swim()

c=ClownFish()
c.swim()

print("Showing off polymorphism:")
for fish in (s,c):
    fish.swim_backwards()
# Out:
# Shark is swimming
# ClownFish can swim
# Showing off polymorphism:
# Shark cannot swim backwards
# ClownFish can swim backwards

# %%
def swimming(fish):
    fish.swim()

swimming(s)
swimming(c)
# Out:
# Shark is swimming
# ClownFish can swim

# %%
class Lionfish(Fish):
    def swim_backwards(self):
        print("Lionfish cannot swim backwards")
    def skeleton(self):
        print("Lionfish skeleton is made up of bone")

l=Lionfish()
l.swim()
swimming(l)
# Out:
# Fish is now swimming
# Fish is now swimming

# %%
class LionfishTwo:
    def swim_backwards(self):
        print("LionfishTwo may swim backwards")
    def skeleton(self):
        print("LionfishTwo skeleton is made up of bone")

l2=LionfishTwo()
swimming(l2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 8
#       5         print("LionfishTwo skeleton is made up of bone")
#       7 l2=LionfishTwo()
# ----> 8 swimming(l2)
#
# Cell In[43], line 2, in swimming(fish)
#       1 def swimming(fish):
# ----> 2     fish.swim()
#
# AttributeError: 'LionfishTwo' object has no attribute 'swim'

# %% [markdown]
# ### Explicit Instance Attributes

# %%
class Student:
    def __init__(self,first_name,last_name):
        self.first_name=first_name
        self.last_name=last_name

    def verify_registration_status(self):
        status=self.get_status()
        self.status_verified=status=='registered'

    def get_guardian_name(self):
        self.guardian=""

    def get_status(self):
        status=query_database(self.first_name,slef.last_name)
        return status

# Best Practice
class Student:
    def __init__(self,first_name,last_name):
        self.first_name=first_name
        self.last_name=last_name
        self.status_verified=None
        self.guardian=None

# %% [markdown]
# ### Use of Properties

# %%
class Student:
    def __init__(self,first_name,last_name):
        self.first_name=first_name
        self.last_name=last_name

    @property
    def name(self):
        print('Getter for the name')
        return f'{self.first_name} {self.last_name}'

    @name.setter
    def name(self,name):
        print("Setter for the name")
        self.first_name, self.last_name=name.split()

student=Student('Manvith','Vishwanatham')
print('Student Name: ',student.name)
student.name='Yukthi Reddy'
print('After setting: ',student.name)
# Out:
# Getter for the name
# Student Name:  Manvith Vishwanatham
# Setter for the name
# Getter for the name
# After setting:  Yukthi Reddy

# %% [markdown]
# ### Meaningful String Representations

# %%
class Person:
    def __init__(self,person_name,person_age):
        self.name=person_name
        self.age=person_age

    def __str__(self):
        return f'Person name is {self.name} and age is {self.age}'

    def __repr__(self):
        return f'Person(name={self.name}, age={self.age})'

p=Person('Manvith',22)
print(p)
print(p.__str__())
print(p.__repr__())
print(repr(p))
# Out:
# Person name is Manvith and age is 22
# Person name is Manvith and age is 22
# Person(name=Manvith, age=22)
# Person(name=Manvith, age=22)

# %% [markdown]
# ### Class and static methods

# %%
from datetime import date

class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age

    @classmethod
    def fromBirthYear(cls,name,year):
        return cls(name,date.today().year-year)

    @staticmethod
    def isAdult(age):
        return age>=18

p1=Person('Manvith',21)
p2=Person.fromBirthYear('Yukthi',2001)

print(p1.age)
print(p2.age)

print(p1.isAdult(19))
print(Person.isAdult(17))
print(p2.isAdult(23))
# Out:
# 21
# 24
# True
# False
# True

# %% [markdown]
# ### Encapsulation using private attributes

# %%
class Student:
    def get_mean_gpa(self):
        grades=self._get_grades()
        gpa_list=Student._converted_gpa_from_grades(grades)
        return sum(gpa_list)/len(gpa_list)

    def _get_grades(self):
        grades=[95,97,92,83]
        return grades

    @staticmethod
    def _converted_gpa_from_grades(grades):
        gpa_list=[4.0,4.0,3.6,3.5]
        return gpa_list

# %% [markdown]
# ### Seperation od Concerns

# %%
class Student:
    def __init__(self,first_name,last_name,student_id):
        self.first_name=first_name
        self.last_name=last_name
        self.student_id=student_id

    def check_account_balance(self):
        account_number=get_account_number(self.student_id)
        balance=get_balance(account_number)
        return balance

    def load_money(self,amount):
        account_number=get_account_number(self,student_id)
        balance=get_balance(account_number)
        balance+=amount
        update_balance(account_number,balance)

# %% [markdown]
# ### Decoupling

# %%
class Student:
    def __init__(self,first_name,last_name,student_id):
        self.first_name=first_name
        self.last_name=last_name
        self.student_id=student_id
        self.account=Account(self.student_id)

    def check_account_balance(self):
        return self.account.get_balance()

    def load_money(self,amount):
        self.account.load_money(amount)

class Account:
    def __init__(self,student_id):
        self.student_id=student_id
        self.balance=400

    def get_balance(self):
        return self.balance

    def load_money(self,amount):
        self.balance+=amount
        self.save_to_database()

# %% [markdown]
# ### Documentation

# %%
class BankAccount:
    """
    A class used to represent a bank account.
    Attributes
    ----------
    __MIN_BALANCE : int
        minimum allowed balance
    Methods
    -------
    deposit(amount=0)
        adds amount to balance
    withdraw(amount=0)
        subtracts amount from balance
    from_csv(filepath)
        return class instance from csv file
    """
    __MIN_BALANCE=-10_000
    def __init__(self,owner,account_number,balance=0):
        self._owner=owner
        self._account_number=account_number
        self._created_at=datetime.now().date()
        if balance<self.__MIN_BALANCE:
            raise ValueError("Balance too small!")
        else:
            self._balance=balance

    def __eq__(self,other):
        return True if self._account_number==other._account_number else False

    def __str__(self):
        return f"""
        Bank Account:
            Account Owner: {self._owner}
            Account Number: {self._account_number}
            Creation Date: {self._to_dash_date(str(self.created_at))}
            Current Balance: {self._balance}
        """

    def __repr__(self):
        return f"BankAccount(owner='{self._owner}', " \
               f"account_number={self._account_number}, " \
               f"balance={self._balance})"

    @classmethod
    def from_csv(cls,fiepath):
        with open(filepath,'r') as f:
            row=csv.reader(f).__next__()
            owner,account_number=row
        return cls(owner,account_number)

    @staticmethod
    def _to_dash_date(date):
        return date.replace('/','-')

    @property
    def account_number(self):
        return self._account_number

    @property
    def created_at(self):
        return self._created_at

    @property
    def balance(self):
        return self._balance

    @balance.setter
    def balance(self,new_balance):
        if new_balance<self.__MIN_BALANCE:
            raise ValueError("Balance too small!!")
        else:
            self._balance=new_balance

    def deposit(self,amount=0):
        self.balance+=amount

    def withdraw(self,amount=0):
        self.balance-=amount

# %%
class Tires:
    def __init__(self,num_tires):
        self.num_tires=num_tires
    def display(self):
        print('Number of tires: ',self.num_tires)

class Doors:
    def __init__(self,num_doors):
        self.num_doors=num_doors
    def display(self):
        print('Number of doors: ',self.num_doors)

class Engine:
    def __init__(self,capacity):
        self.capacity=capacity
    def display(self):
        print('Capacity: ',self.capacity)

class Car:
    def __init__(self,num_tires,num_doors,capacity):
        self.tires=Tires(num_tires)
        self.doors=Doors(num_doors)
        self.capacity=Engine(capacity)

    def print_details(self):
        print("Car Details: ")
        self.tires.display()
        self.doors.display()
        self.capacity.display()

car = Car(4, 4, 1600)
car.print_details()
# Out:
# Car Details:
# Number of tires:  4
# Number of doors:  4
# Capacity:  1600

# %%
class A:
    def __repr__(self):
        return "1"

class B(A):
    def __repr__(self):
        return "2"

class C(B):
    def __repr__(self):
        return "3"

o1=A()
o2=B()
o3=C()
print(o1,o2,o3)
# Out:
# 1 2 3

# %%
class A:
    def __init__(self):
        self.multiply(15)
        print(self.i)

    def multiply(self,i):
        self.i=4*i
class B(A):
    def __init__(self):
        super().__init__()

    def multiply(self,i):
        self.i=2*i

obj=B()
# Out:
# 30

# %%
class Demo:
    def check(self):
        return "Demo's check"
    def display(self):
        print(self.check())

class Demo_Derived(Demo):
    def check(self):
        return "Derived's check"

Demo().display()
Demo_Derived().display()
# Out:
# Demo's check
# Derived's check

# %%
import math

class Rectangle:
    def __init__(self,width,height):
        self.width=width
        self.height=height

    def get_area(self):
        return self.width*self.height

class Circle:
    def __init__(self,radius):
        self.radius=radius
    def get_area(self):
        return math.pi*self.radius*self.radius

# Polymorphism Example
shapes = [Rectangle(4, 5), Circle(3)]

for shape in shapes:
    print(f"The area is: {shape.get_area():.2f}")
# Out:
# The area is: 20.00
# The area is: 28.27

# %%
import math

class Shape:
    def get_area(self):
        pass

class Rectangle(Shape):
    def __init__(self,width,height):
        self.width=width
        self.height=height

    def get_area(self):
        return self.width*self.height

class Circle(Shape):
    def __init__(self,radius):
        self.radius=radius
    def get_area(self):
        return math.pi*self.radius*self.radius

# Polymorphism Example
shapes = [Rectangle(4, 5), Circle(3)]

for shape in shapes:
    print(f"The area is: {shape.get_area():.2f}")
# Out:
# The area is: 20.00
# The area is: 28.27

# %%
class FullTimeEmployee:
    def __init__(self,name,position,salary):
        self.name=name
        self.position=position
        self.salary=salary

    def bonus(self):
        self.salary+=0.5*self.salary
        return self.salary

class PartTimeEmployee(FullTimeEmployee):
    def __init__(self,name,position,salary):
        self.name=name
        self.position=position
        self.salary=salary

    def bonus(self):
        self.salary+=0.1*self.salary
        return self.salary

emp1 = FullTimeEmployee('John', 'Frontend Developer', 10000)
print(emp1.bonus())
emp2 = PartTimeEmployee('Danise', 'Data Scientist', 20000)
print(emp2.bonus())
# Out:
# 15000.0
# 22000.0

# %%
class Vehicle:
    def __init__(self,fare):
        self.fare=fare

    def __add__(self,other):
        return self.fare+other.fare

    def __lt__(self,other):
        return self.fare<other.fare

bus=Vehicle(20)
car=Vehicle(30)

total_fare=bus+car
print(total_fare)

compare=bus<car
print(compare)
# Out:
# 50
# True

# %%
class Complex:
    def __init__(self,x,y):
        self.x=x
        self.y=y

    def __add__(self, other):
        return Complex(self.x + other.x, self.y + other.y)

    def __sub__(self, other):
        return Complex(self.x - other.x, self.y - other.y)

    def __str__(self):
        sign = '+' if self.y >= 0 else '-'
        return f'{self.x} {sign} {abs(self.y)}i'

x=Complex(2,1)
y=Complex(3,9)
print(x+y)
print(x-y)
# Out:
# 5 + 10i
# -1 - 8i

# %%
class City:
    def __init__(self,name):
        self.name=name

    def display(self):
        print("Gneric Message")

class Adelaide(City):
    def display(self):
        print("SA")

class Melbourne(City):
    def display(self):
        print("Victoria")

class Sydney(City):
    def display(self):
        print("New South Wales")

cities=[Adelaide('Adelaide'),Melbourne('Melbourne'),Sydney('Sydney')]
for city in cities:
    city.display()
# Out:
# SA
# Victoria
# New South Wales

# %%
class Device:
    def __init__(self,name,price):
        self.name=name
        self.price=price

    def device_details(self):
        print('Name: ',self.name)
        print('Price: ',self.price)

class Phone(Device):
    def __init__(self,name,price,color):
        super().__init__(name,price)
        self.color=color

    def device_details(self):
        print('Name: ',self.name)
        print('Price: ',self.price)
        print('Color: ',self.color)

class Laptop(Device):
    def __init__(self,name,price,size):
        super().__init__(name,price)
        self.size=size

    def device_details(self):
        print('Name: ',self.name)
        print('Price: ',self.price)
        print('Size: ',self.size)

p=Phone('Iphone 18 Pro Max',2000,'Blue')
l=Laptop('Macbook M4 air',1500,16)
p.device_details()
print("---------------")
l.device_details()
# Out:
# Name:  Iphone 18 Pro Max
# Price:  2000
# Color:  Blue
# ---------------
# Name:  Macbook M4 air
# Price:  1500
# Size:  16

# %%
# 1. Duck Typing
class Car:
    def start(self):
        print("Car engine started.")

class Bike:
    def start(self):
        print("Bike engine started.")

def start_vehicle(vehicle):
    vehicle.start()

car = Car()
bike = Bike()

start_vehicle(car)
start_vehicle(bike)

# 2. Operator Overloading
class Complex:
    def __init__(self, real, imag):
        self.real = real
        self.imag = imag

    def __add__(self, other):
        return Complex(self.real + other.real, self.imag + other.imag)

    def __str__(self):
        sign = '+' if self.imag >= 0 else '-'
        return f"{self.real} {sign} {abs(self.imag)}i"

c1 = Complex(3, 2)
c2 = Complex(1, 7)

print("Sum:", c1 + c2)

# 3. Method Overloading
class Calculator:
    def add(self, a=None, b=None, c=None):
        if a is not None and b is not None and c is not None:
            return a + b + c
        elif a is not None and b is not None:
            return a + b
        elif a is not None:
            return a
        else:
            return 0

calc = Calculator()
print(calc.add(5, 10))
print(calc.add(2, 3, 4))
print(calc.add(7))

# 4. Method Overriding
class Device:
    def device_details(self):
        print("Generic device details.")

class Phone(Device):
    def device_details(self):
        print("This is a smartphone with 128GB storage.")

class Laptop(Device):
    def device_details(self):
        print("This is a laptop with 16-inch display.")

devices = [Phone(), Laptop()]

for d in devices:
    d.device_details()
# Out:
# Car engine started.
# Bike engine started.
# Sum: 4 + 9i
# 15
# 9
# 7
# This is a smartphone with 128GB storage.
# This is a laptop with 16-inch display.

# %%
class BankAccount:
    def set_owner(self, owner):
        self.owner = owner
        
    def set_balance(self, balance):
        self.balance = balance
        
    def deposit(self, amount):
        self.balance += amount
        
    def withdraw(self, amount):
        self.balance -= amount

from math import pi

class square:
    def __init__(self, length):
        self.l = length
    
    def perimeter(self):
        return 4 * (self.l)
    
    def area(self):
        return self.l * self.l
    
class Circle:
    def __init__(self, radius):
        self.r = radius
    
    def perimeter(self):
        return 2 * pi * self.r
    
    def area(self):
        return pi * self.r ** 2
    
sqr = square(10)
c1 = Circle(4)
print("Perimeter computed for square: ", sqr.perimeter())
print("Area computed for square: ", sqr.area())
print("Perimeter computed for Circle: ", c1.perimeter())
print("Area computed for Circle: ", c1.area())
# Out:
# Perimeter computed for square:  40
# Area computed for square:  100
# Perimeter computed for Circle:  25.132741228718345
# Area computed for Circle:  50.26548245743669

# %%
class Vehicle:
    def __init__(self,name,color,price):
        self.name=name
        self.color=color
        self.price=price

    def show(self):
        print('Name: ',self.name)
        print('Color: ',self.color)
        print('Price: ',self.price)
        print('Max Speed: ',self.speed())
        print('Change Gear: ',self.change_gear())

    def speed(self):
        return 150

    def change_gear(self):
        return 5

class Car(Vehicle):
    def speed(self):
        return 240

    def change_gear(self):
        return 6

class Truck(Vehicle):
    def speed(self):
        return 200

    def change_gear(self):
        return 8

# Car Object
car = Car('Car x1', 'Red', 20000)
car.show()
# calls methods from Car class
print(car.speed())
print(car.change_gear())

# Vehicle Object
vehicle = Vehicle('Truck x1', 'white', 75000)
vehicle.show()
# calls method from a Vehicle class
print(vehicle.speed())
print(vehicle.change_gear())
# Out:
# Name:  Car x1
# Color:  Red
# Price:  20000
# Max Speed:  240
# Change Gear:  6
# 240
# 6
# Name:  Truck x1
# Color:  white
# Price:  75000
# Max Speed:  150
# Change Gear:  5
# 150
# 5

# %%
class BankAccount:
    """
    A class used to represent an bank account.
    Attributes
    ----------
    __MIN_BALANCE : int
        minimum allowed balance
    Methods
    -------
    deposit(amount=0)
        adds amount to balance
    withdraw(amount=0)
        subtracts amount from balance
    from_csv(filepath)
        returns class instance from csv file
    """
    
    __MIN_BALANCE = -10_000

    
    def __init__(self, owner, account_number, balance=0):
        self._owner = owner    
        self._account_number = account_number
        self._created_at = datetime.now().date()
        if balance < self.__MIN_BALANCE:
            raise ValueError("Balance to small!")
        else:
            self._balance = balance
        
    def __eq__(self, other):
        return True if self._account_number == other._account_number else False
    
    def __str__(self):
        return f"""
        Bank Account:
            Account Owner: {self._owner}
            Account Number: {self._account_number}
            Creation Date: {self._to_dash_date(str(self.created_at))}
            Current Balance: {self._balance}
        """
    
    def __repr__(self):
        return f"BankAccount(owner='{self._owner}', " \
               f"account_number={self._account_number}, " \
               f"balance={self._balance})"
    
    @classmethod
    def from_csv(cls, filepath):
        with open(filepath, "r") as f:
            row = csv.reader(f).__next__()
            owner, account_number = row
        return cls(owner, account_number)
    
    @staticmethod
    def _to_dash_date(date):
        # utility to replace "/" with "-" in a date
        return date.replace("/", "-") 
    
    @property
    def account_number(self):
        return self._account_number
    
    @property
    def created_at(self):
        return self._created_at
    
    @property
    def balance(self):
        return self._balance
    
    @balance.setter
    def balance(self, new_balance):
        if new_balance < self.__MIN_BALANCE:
            raise ValueError("Balance to small!")
        else:
            self._balance = new_balance
        
    def deposit(self, amount=0):
        self.balance += amount
        
    def withdraw(self, amount=0):
        self.balance -= amount
